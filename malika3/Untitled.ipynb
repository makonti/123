# %%
import pandas as pd
df=pd.read_csv('Restaurant.csv')

# %%
df['day'].value_counts().plot(kind='bar',grid=True, title='Количество посетителей')
# Out:
# <Axes: title={'center': 'Количество посетителей'}, xlabel='day'>
